# %% [markdown]
# ### This script uses the Facebook's open source software 'Prophet' to forecast the spread of COVID-19 worlwide for a defined future timeframe. We are using Prophet here beacuse the model to missing data, shifts in the trend and handles outliers well

# %% [markdown]
# ![alt text](https://cdn.weka-fachmedien.de/thumbs/media_uploads/images/1584632058-339-worrlgjo3.jpg.950x534.jpg)

# %%
#import the necessary packages
import pandas as pd
from fbprophet import Prophet

# Disable warnings 
import warnings
warnings.filterwarnings('ignore')

# %%
#loading the required datasets
df = pd.read_csv('../data/covid_19_data.csv')
df.rename(columns={'ObservationDate':'Date', 'Country/Region':'Country'}, inplace=True)
#df['Date'] = pd.to_datetime(df['Date'])
df.drop('SNo', axis=1, inplace = True)

df_confirmed = pd.read_csv("../data/time_series_covid_19_confirmed.csv")
df_recovered = pd.read_csv("../data/time_series_covid_19_recovered.csv")
df_deaths = pd.read_csv("../data/time_series_covid_19_deaths.csv")

df_confirmed.rename(columns={'Country/Region':'Country'}, inplace=True)
df_recovered.rename(columns={'Country/Region':'Country'}, inplace=True)
df_deaths.rename(columns={'Country/Region':'Country'}, inplace=True)

# %%
confirmed = df.groupby('Date').sum()['Confirmed'].reset_index()
deaths = df.groupby('Date').sum()['Deaths'].reset_index()
recovered = df.groupby('Date').sum()['Recovered'].reset_index()

# %% [markdown]
# The input to Prophet is always a dataframe with two columns: **ds** and **y**. The **ds (datestamp)** column should be of a format expected by Pandas, ideally YYYY-MM-DD for a date or YYYY-MM-DD HH:MM:SS for a timestamp. The y column must be numeric, and represents the measurement we wish to forecast.

# %%
confirmed['Confirmed'] = confirmed['Confirmed'].astype(int)
deaths['Deaths'] = deaths['Deaths'].astype(int)
recovered['Recovered'] = recovered['Recovered'] .astype(int)

confirmed.columns = ['ds','y']
deaths.columns = ['ds','y']
recovered.columns = ['ds','y']

confirmed.name = "Confirmed Cases"
deaths.name = "Death Cases"
recovered.name = "Recovery Cases"

# %% [markdown]
# ## Forecasting global confirmed cases using Prophet (Base model)
#
# Forecasting the comfirmed cases globally for a week's timeframe in advance, with 98% confidence interval. We are use the basic model here with no tweaking of seasonality-related parameters and additional regressors.

# %%
def covid_19_prediction(training_data, number_of_days_in_advance):
    
    model = Prophet(interval_width=0.98)
    model.fit(training_data)
    future_cases = model.make_future_dataframe(periods=number_of_days_in_advance)
    
    ### Forecasting the future confirmed cases globally for the next 1 week
    forecast = model.predict(future_cases)
    forecast_coming_week = forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail(7)
    forecast_coming_week = forecast_coming_week[1:]
    forecast_coming_week.ds = forecast_coming_week.ds.dt.day_name()
    forecast_coming_week.rename(columns = {'ds':'day_of_the_week','yhat':'prediction', 
                                     'yhat_lower':'prediction_lower_bound',
                                    'yhat_upper':'prediction_upper_bound'}, inplace=True)
    
    forecast_coming_week.set_index('day_of_the_week', inplace=True)
    forecast_coming_week['prediction' ] = round(forecast_coming_week.prediction).astype(int)
    forecast_coming_week['prediction_lower_bound'] = round(forecast_coming_week.prediction_lower_bound).astype(int)
    forecast_coming_week['prediction_upper_bound'] = round(forecast_coming_week.prediction_upper_bound).astype(int)
    
    ax = forecast_coming_week.plot(kind="bar",width=0.6, edgecolor='y',  figsize=(12,8), style='.-')
    ax.set_title("Predictions of %s in coming days including an upper an lower bound" %(training_data.name), fontsize=15)
    ax.set_ylabel("Count", fontsize=12)
    ax.set_xlabel("Day of the week", fontsize=12)

    for p in ax.patches:
        ax.annotate(str(p.get_height()), (p.get_x() * 1.02, p.get_height() * .8), family="monospace",
                    va='center', ha='center', horizontalalignment='right', verticalalignment='top', 
                    rotation=90, size=12)
        
    #saving the visualization
    fig= ax.get_figure()
    fig.tight_layout()
    fig.savefig("../visualizations/predictions/COVID-19_prediction_of_%s.png" %(training_data.name))   
    
    #Plotting the forecast with the confidence interval of 98 percent
    confirmed_forecast_plot = model.plot(forecast).savefig("../visualizations/predictions/COVID-19_prediction_fit_of_%s.png" %(training_data.name))
    
    model.plot_components(forecast).savefig("../visualizations/predictions/COVID-19_prediction_trend_of_%s.png" %(training_data.name))
    
    return model, forecast, forecast_coming_week

# %%
trained_model, forecast, forecast_coming_week = covid_19_prediction(confirmed, 7)
# Out:
# INFO:numexpr.utils:Note: NumExpr detected 12 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# INFO:numexpr.utils:NumExpr defaulting to 8 threads.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
trained_model, forecast, forecast_coming_week = covid_19_prediction(recovered, 7)
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
trained_model, forecast, forecast_coming_week = covid_19_prediction(deaths, 7)
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
forecast_coming_week.style.background_gradient(cmap='Reds')
# Out:
# <style  type="text/css" >
#     #T_6b4784d0_832e_11ea_b263_acde48001122row0_col0 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_6b4784d0_832e_11ea_b263_acde48001122row0_col1 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_6b4784d0_832e_11ea_b263_acde48001122row0_col2 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_6b4784d0_832e_11ea_b263_acde48001122row1_col0 {
#             background-color:  #fdc7b2;
#             color:  #000000;
#         }    #T_6b4784d0_832e_11ea_b263_acde48001122row1_col1 {
#             background-color:  #fcc2aa;
#             color:  #000000;
#         }    #T_6b4784d0_832e_11ea_b263_acde48001122row1_col2 {
#             background-color:  #fdcbb6;
#             color:  #000000;
#         }    #T_6b4784d0_832e_11ea_b263_acde48001122row2_col0 {
#             background-color:  #fc8666;
#             color:  #000000;
#         }    #T_6b4784d0_832e_11ea_b263_acde48001122row2_col1 {
#             background-color:  #fb7b5b;
#             color:  #000000;
#         }    #T_6b4784d0_832e_11ea_b263_acde48001122row2_col2 {
#             background-color:  #fc8e6e;
#             color:  #000000;
#         }    #T_6b4784d0_832e_11ea_b263_acde48001122row3_col0 {
#             background-color:  #f03d2d;
#             color:  #f1f1f1;
#         }    #T_6b4784d0_832e_11ea_b263_acde48001122row3_col1 {
#             background-color:  #e93529;
#             color:  #f1f1f1;
#         }    #T_6b4784d0_832e_11ea_b263_acde48001122row3_col2 {
#             background-color:  #f14130;
#             color:  #f1f1f1;
#         }    #T_6b4784d0_832e_11ea_b263_acde48001122row4_col0 {
#             background-color:  #b71319;
#             color:  #f1f1f1;
#         }    #T_6b4784d0_832e_11ea_b263_acde48001122row4_col1 {
#             background-color:  #ac1117;
#             color:  #f1f1f1;
#         }    #T_6b4784d0_832e_11ea_b263_acde48001122row4_col2 {
#             background-color:  #b81419;
#             color:  #f1f1f1;
#         }    #T_6b4784d0_832e_11ea_b263_acde48001122row5_col0 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_6b4784d0_832e_11ea_b263_acde48001122row5_col1 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_6b4784d0_832e_11ea_b263_acde48001122row5_col2 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }</style><table id="T_6b4784d0_832e_11ea_b263_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >prediction</th>        <th class="col_heading level0 col1" >prediction_lower_bound</th>        <th class="col_heading level0 col2" >prediction_upper_bound</th>    </tr>    <tr>        <th class="index_name level0" >day_of_the_week</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_6b4784d0_832e_11ea_b263_acde48001122level0_row0" class="row_heading level0 row0" >Tuesday</th>
#                         <td id="T_6b4784d0_832e_11ea_b263_acde48001122row0_col0" class="data row0 col0" >174919</td>
#                         <td id="T_6b4784d0_832e_11ea_b263_acde48001122row0_col1" class="data row0 col1" >172263</td>
#                         <td id="T_6b4784d0_832e_11ea_b263_acde48001122row0_col2" class="data row0 col2" >177500</td>
#             </tr>
#             <tr>
#                         <th id="T_6b4784d0_832e_11ea_b263_acde48001122level0_row1" class="row_heading level0 row1" >Wednesday</th>
#                         <td id="T_6b4784d0_832e_11ea_b263_acde48001122row1_col0" class="data row1 col0" >181778</td>
#                         <td id="T_6b4784d0_832e_11ea_b263_acde48001122row1_col1" class="data row1 col1" >178875</td>
#                         <td id="T_6b4784d0_832e_11ea_b263_acde48001122row1_col2" class="data row1 col2" >184969</td>
#             </tr>
#             <tr>
#                         <th id="T_6b4784d0_832e_11ea_b263_acde48001122level0_row2" class="row_heading level0 row2" >Thursday</th>
#                         <td id="T_6b4784d0_832e_11ea_b263_acde48001122row2_col0" class="data row2 col0" >188598</td>
#                         <td id="T_6b4784d0_832e_11ea_b263_acde48001122row2_col1" class="data row2 col1" >185157</td>
#                         <td id="T_6b4784d0_832e_11ea_b263_acde48001122row2_col2" class="data row2 col2" >192180</td>
#             </tr>
#             <tr>
#                         <th id="T_6b4784d0_832e_11ea_b263_acde48001122level0_row3" class="row_heading level0 row3" >Friday</th>
#                         <td id="T_6b4784d0_832e_11ea_b263_acde48001122row3_col0" class="data row3 col0" >195388</td>
#                         <td id="T_6b4784d0_832e_11ea_b263_acde48001122row3_col1" class="data row3 col1" >191023</td>
#                         <td id="T_6b4784d0_832e_11ea_b263_acde48001122row3_col2" class="data row3 col2" >200339</td>
#             </tr>
#             <tr>
#                         <th id="T_6b4784d0_832e_11ea_b263_acde48001122level0_row4" class="row_heading level0 row4" >Saturday</th>
#                         <td id="T_6b4784d0_832e_11ea_b263_acde48001122row4_col0" class="data row4 col0" >201792</td>
#                         <td id="T_6b4784d0_832e_11ea_b263_acde48001122row4_col1" class="data row4 col1" >196869</td>
#                         <td id="T_6b4784d0_832e_11ea_b263_acde48001122row4_col2" class="data row4 col2" >207962</td>
#             </tr>
#             <tr>
#                         <th id="T_6b4784d0_832e_11ea_b263_acde48001122level0_row5" class="row_heading level0 row5" >Sunday</th>
#                         <td id="T_6b4784d0_832e_11ea_b263_acde48001122row5_col0" class="data row5 col0" >207990</td>
#                         <td id="T_6b4784d0_832e_11ea_b263_acde48001122row5_col1" class="data row5 col1" >201211</td>
#                         <td id="T_6b4784d0_832e_11ea_b263_acde48001122row5_col2" class="data row5 col2" >215134</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ## Forecasting global death cases using Prophet (Base model)
#
# Forecasting the death cases globally for a week's timeframe in advance, with 98% confidence interval. We are use the basic model here with no tweaking of seasonality-related parameters and additional regressors.

# %%
model = Prophet(interval_width=0.98)
model.fit(deaths)
future_death_cases = model.make_future_dataframe(periods=7)
#future_death_cases.tail(7)
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %% [markdown]
# ### Forecasting the future confirmed cases globally for the next 1 week

# %%
forecast = model.predict(future_death_cases)
forecast_coming_week = forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail(7)

# %%
forecast_coming_week.style.background_gradient(cmap='Reds')
# Out:
# <style  type="text/css" >
#     #T_6c97b4fe_832e_11ea_b607_acde48001122row0_col1 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_6c97b4fe_832e_11ea_b607_acde48001122row0_col2 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_6c97b4fe_832e_11ea_b607_acde48001122row0_col3 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_6c97b4fe_832e_11ea_b607_acde48001122row1_col1 {
#             background-color:  #fdd3c1;
#             color:  #000000;
#         }    #T_6c97b4fe_832e_11ea_b607_acde48001122row1_col2 {
#             background-color:  #fdccb8;
#             color:  #000000;
#         }    #T_6c97b4fe_832e_11ea_b607_acde48001122row1_col3 {
#             background-color:  #fed8c7;
#             color:  #000000;
#         }    #T_6c97b4fe_832e_11ea_b607_acde48001122row2_col1 {
#             background-color:  #fc9d7f;
#             color:  #000000;
#         }    #T_6c97b4fe_832e_11ea_b607_acde48001122row2_col2 {
#             background-color:  #fc9373;
#             color:  #000000;
#         }    #T_6c97b4fe_832e_11ea_b607_acde48001122row2_col3 {
#             background-color:  #fca486;
#             color:  #000000;
#         }    #T_6c97b4fe_832e_11ea_b607_acde48001122row3_col1 {
#             background-color:  #fa6547;
#             color:  #000000;
#         }    #T_6c97b4fe_832e_11ea_b607_acde48001122row3_col2 {
#             background-color:  #f7593f;
#             color:  #000000;
#         }    #T_6c97b4fe_832e_11ea_b607_acde48001122row3_col3 {
#             background-color:  #fb7050;
#             color:  #000000;
#         }    #T_6c97b4fe_832e_11ea_b607_acde48001122row4_col1 {
#             background-color:  #de2b25;
#             color:  #f1f1f1;
#         }    #T_6c97b4fe_832e_11ea_b607_acde48001122row4_col2 {
#             background-color:  #d52221;
#             color:  #f1f1f1;
#         }    #T_6c97b4fe_832e_11ea_b607_acde48001122row4_col3 {
#             background-color:  #e63328;
#             color:  #f1f1f1;
#         }    #T_6c97b4fe_832e_11ea_b607_acde48001122row5_col1 {
#             background-color:  #ad1117;
#             color:  #f1f1f1;
#         }    #T_6c97b4fe_832e_11ea_b607_acde48001122row5_col2 {
#             background-color:  #ab1016;
#             color:  #f1f1f1;
#         }    #T_6c97b4fe_832e_11ea_b607_acde48001122row5_col3 {
#             background-color:  #af1117;
#             color:  #f1f1f1;
#         }    #T_6c97b4fe_832e_11ea_b607_acde48001122row6_col1 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_6c97b4fe_832e_11ea_b607_acde48001122row6_col2 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_6c97b4fe_832e_11ea_b607_acde48001122row6_col3 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }</style><table id="T_6c97b4fe_832e_11ea_b607_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >ds</th>        <th class="col_heading level0 col1" >yhat</th>        <th class="col_heading level0 col2" >yhat_lower</th>        <th class="col_heading level0 col3" >yhat_upper</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_6c97b4fe_832e_11ea_b607_acde48001122level0_row0" class="row_heading level0 row0" >89</th>
#                         <td id="T_6c97b4fe_832e_11ea_b607_acde48001122row0_col0" class="data row0 col0" >2020-04-20 00:00:00</td>
#                         <td id="T_6c97b4fe_832e_11ea_b607_acde48001122row0_col1" class="data row0 col1" >168210.025096</td>
#                         <td id="T_6c97b4fe_832e_11ea_b607_acde48001122row0_col2" class="data row0 col2" >165471.505449</td>
#                         <td id="T_6c97b4fe_832e_11ea_b607_acde48001122row0_col3" class="data row0 col3" >170729.831373</td>
#             </tr>
#             <tr>
#                         <th id="T_6c97b4fe_832e_11ea_b607_acde48001122level0_row1" class="row_heading level0 row1" >90</th>
#                         <td id="T_6c97b4fe_832e_11ea_b607_acde48001122row1_col0" class="data row1 col0" >2020-04-21 00:00:00</td>
#                         <td id="T_6c97b4fe_832e_11ea_b607_acde48001122row1_col1" class="data row1 col1" >174919.132155</td>
#                         <td id="T_6c97b4fe_832e_11ea_b607_acde48001122row1_col2" class="data row1 col2" >172443.447417</td>
#                         <td id="T_6c97b4fe_832e_11ea_b607_acde48001122row1_col3" class="data row1 col3" >177487.572695</td>
#             </tr>
#             <tr>
#                         <th id="T_6c97b4fe_832e_11ea_b607_acde48001122level0_row2" class="row_heading level0 row2" >91</th>
#                         <td id="T_6c97b4fe_832e_11ea_b607_acde48001122row2_col0" class="data row2 col0" >2020-04-22 00:00:00</td>
#                         <td id="T_6c97b4fe_832e_11ea_b607_acde48001122row2_col1" class="data row2 col1" >181777.772897</td>
#                         <td id="T_6c97b4fe_832e_11ea_b607_acde48001122row2_col2" class="data row2 col2" >178975.471484</td>
#                         <td id="T_6c97b4fe_832e_11ea_b607_acde48001122row2_col3" class="data row2 col3" >184911.145181</td>
#             </tr>
#             <tr>
#                         <th id="T_6c97b4fe_832e_11ea_b607_acde48001122level0_row3" class="row_heading level0 row3" >92</th>
#                         <td id="T_6c97b4fe_832e_11ea_b607_acde48001122row3_col0" class="data row3 col0" >2020-04-23 00:00:00</td>
#                         <td id="T_6c97b4fe_832e_11ea_b607_acde48001122row3_col1" class="data row3 col1" >188598.214005</td>
#                         <td id="T_6c97b4fe_832e_11ea_b607_acde48001122row3_col2" class="data row3 col2" >185229.206856</td>
#                         <td id="T_6c97b4fe_832e_11ea_b607_acde48001122row3_col3" class="data row3 col3" >191912.077340</td>
#             </tr>
#             <tr>
#                         <th id="T_6c97b4fe_832e_11ea_b607_acde48001122level0_row4" class="row_heading level0 row4" >93</th>
#                         <td id="T_6c97b4fe_832e_11ea_b607_acde48001122row4_col0" class="data row4 col0" >2020-04-24 00:00:00</td>
#                         <td id="T_6c97b4fe_832e_11ea_b607_acde48001122row4_col1" class="data row4 col1" >195387.540081</td>
#                         <td id="T_6c97b4fe_832e_11ea_b607_acde48001122row4_col2" class="data row4 col2" >191314.090889</td>
#                         <td id="T_6c97b4fe_832e_11ea_b607_acde48001122row4_col3" class="data row4 col3" >199478.406148</td>
#             </tr>
#             <tr>
#                         <th id="T_6c97b4fe_832e_11ea_b607_acde48001122level0_row5" class="row_heading level0 row5" >94</th>
#                         <td id="T_6c97b4fe_832e_11ea_b607_acde48001122row5_col0" class="data row5 col0" >2020-04-25 00:00:00</td>
#                         <td id="T_6c97b4fe_832e_11ea_b607_acde48001122row5_col1" class="data row5 col1" >201791.712316</td>
#                         <td id="T_6c97b4fe_832e_11ea_b607_acde48001122row5_col2" class="data row5 col2" >196455.282044</td>
#                         <td id="T_6c97b4fe_832e_11ea_b607_acde48001122row5_col3" class="data row5 col3" >207636.112184</td>
#             </tr>
#             <tr>
#                         <th id="T_6c97b4fe_832e_11ea_b607_acde48001122level0_row6" class="row_heading level0 row6" >95</th>
#                         <td id="T_6c97b4fe_832e_11ea_b607_acde48001122row6_col0" class="data row6 col0" >2020-04-26 00:00:00</td>
#                         <td id="T_6c97b4fe_832e_11ea_b607_acde48001122row6_col1" class="data row6 col1" >207989.978025</td>
#                         <td id="T_6c97b4fe_832e_11ea_b607_acde48001122row6_col2" class="data row6 col2" >201793.870377</td>
#                         <td id="T_6c97b4fe_832e_11ea_b607_acde48001122row6_col3" class="data row6 col3" >214652.846457</td>
#             </tr>
#     </tbody></table>

# %%
#Plotting the forecast with the confidence interval of 98 percent
death_forecast_plot = model.plot(forecast)

# %%
#plotting the forcast for upcoming 7 days
death_forecast_plot = model.plot_components(forecast)

# %% [markdown]
# ## Forecasting global recovery cases using Prophet (Base model)
#
# Forecasting the recovery cases globally for a week's timeframe in advance, with 98% confidence interval. We are use the basic model here with no tweaking of seasonality-related parameters and additional regressors.

# %%
model = Prophet(interval_width=0.98)
model.fit(recovered)
future_recovered_cases = model.make_future_dataframe(periods=7)
#future_death_cases.tail(7)
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %% [markdown]
# ### Forecasting the future confirmed cases globally for the next 1 week

# %%
forecast = model.predict(future_recovered_cases)
forecast_coming_week = forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail(7)

# %%
#printing the predicted values for coming week
forecast_coming_week.style.background_gradient(cmap='Reds')
# Out:
# <style  type="text/css" >
#     #T_6e4b6282_832e_11ea_8114_acde48001122row0_col1 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_6e4b6282_832e_11ea_8114_acde48001122row0_col2 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_6e4b6282_832e_11ea_8114_acde48001122row0_col3 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_6e4b6282_832e_11ea_8114_acde48001122row1_col1 {
#             background-color:  #fdd3c1;
#             color:  #000000;
#         }    #T_6e4b6282_832e_11ea_8114_acde48001122row1_col2 {
#             background-color:  #fdccb8;
#             color:  #000000;
#         }    #T_6e4b6282_832e_11ea_8114_acde48001122row1_col3 {
#             background-color:  #fed8c7;
#             color:  #000000;
#         }    #T_6e4b6282_832e_11ea_8114_acde48001122row2_col1 {
#             background-color:  #fc9b7c;
#             color:  #000000;
#         }    #T_6e4b6282_832e_11ea_8114_acde48001122row2_col2 {
#             background-color:  #fc9070;
#             color:  #000000;
#         }    #T_6e4b6282_832e_11ea_8114_acde48001122row2_col3 {
#             background-color:  #fca285;
#             color:  #000000;
#         }    #T_6e4b6282_832e_11ea_8114_acde48001122row3_col1 {
#             background-color:  #fa6547;
#             color:  #000000;
#         }    #T_6e4b6282_832e_11ea_8114_acde48001122row3_col2 {
#             background-color:  #f75c41;
#             color:  #000000;
#         }    #T_6e4b6282_832e_11ea_8114_acde48001122row3_col3 {
#             background-color:  #fb6e4e;
#             color:  #000000;
#         }    #T_6e4b6282_832e_11ea_8114_acde48001122row4_col1 {
#             background-color:  #e12d26;
#             color:  #f1f1f1;
#         }    #T_6e4b6282_832e_11ea_8114_acde48001122row4_col2 {
#             background-color:  #db2824;
#             color:  #f1f1f1;
#         }    #T_6e4b6282_832e_11ea_8114_acde48001122row4_col3 {
#             background-color:  #e32f27;
#             color:  #f1f1f1;
#         }    #T_6e4b6282_832e_11ea_8114_acde48001122row5_col1 {
#             background-color:  #b01217;
#             color:  #f1f1f1;
#         }    #T_6e4b6282_832e_11ea_8114_acde48001122row5_col2 {
#             background-color:  #af1117;
#             color:  #f1f1f1;
#         }    #T_6e4b6282_832e_11ea_8114_acde48001122row5_col3 {
#             background-color:  #b31218;
#             color:  #f1f1f1;
#         }    #T_6e4b6282_832e_11ea_8114_acde48001122row6_col1 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_6e4b6282_832e_11ea_8114_acde48001122row6_col2 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_6e4b6282_832e_11ea_8114_acde48001122row6_col3 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }</style><table id="T_6e4b6282_832e_11ea_8114_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >ds</th>        <th class="col_heading level0 col1" >yhat</th>        <th class="col_heading level0 col2" >yhat_lower</th>        <th class="col_heading level0 col3" >yhat_upper</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_6e4b6282_832e_11ea_8114_acde48001122level0_row0" class="row_heading level0 row0" >89</th>
#                         <td id="T_6e4b6282_832e_11ea_8114_acde48001122row0_col0" class="data row0 col0" >2020-04-20 00:00:00</td>
#                         <td id="T_6e4b6282_832e_11ea_8114_acde48001122row0_col1" class="data row0 col1" >624347.975822</td>
#                         <td id="T_6e4b6282_832e_11ea_8114_acde48001122row0_col2" class="data row0 col2" >609298.728753</td>
#                         <td id="T_6e4b6282_832e_11ea_8114_acde48001122row0_col3" class="data row0 col3" >638392.872312</td>
#             </tr>
#             <tr>
#                         <th id="T_6e4b6282_832e_11ea_8114_acde48001122level0_row1" class="row_heading level0 row1" >90</th>
#                         <td id="T_6e4b6282_832e_11ea_8114_acde48001122row1_col0" class="data row1 col0" >2020-04-21 00:00:00</td>
#                         <td id="T_6e4b6282_832e_11ea_8114_acde48001122row1_col1" class="data row1 col1" >648996.929162</td>
#                         <td id="T_6e4b6282_832e_11ea_8114_acde48001122row1_col2" class="data row1 col2" >635437.926073</td>
#                         <td id="T_6e4b6282_832e_11ea_8114_acde48001122row1_col3" class="data row1 col3" >662160.509593</td>
#             </tr>
#             <tr>
#                         <th id="T_6e4b6282_832e_11ea_8114_acde48001122level0_row2" class="row_heading level0 row2" >91</th>
#                         <td id="T_6e4b6282_832e_11ea_8114_acde48001122row2_col0" class="data row2 col0" >2020-04-22 00:00:00</td>
#                         <td id="T_6e4b6282_832e_11ea_8114_acde48001122row2_col1" class="data row2 col1" >674744.675986</td>
#                         <td id="T_6e4b6282_832e_11ea_8114_acde48001122row2_col2" class="data row2 col2" >660974.369100</td>
#                         <td id="T_6e4b6282_832e_11ea_8114_acde48001122row2_col3" class="data row2 col3" >688738.625190</td>
#             </tr>
#             <tr>
#                         <th id="T_6e4b6282_832e_11ea_8114_acde48001122level0_row3" class="row_heading level0 row3" >92</th>
#                         <td id="T_6e4b6282_832e_11ea_8114_acde48001122row3_col0" class="data row3 col0" >2020-04-23 00:00:00</td>
#                         <td id="T_6e4b6282_832e_11ea_8114_acde48001122row3_col1" class="data row3 col1" >698414.431716</td>
#                         <td id="T_6e4b6282_832e_11ea_8114_acde48001122row3_col2" class="data row3 col2" >682479.370011</td>
#                         <td id="T_6e4b6282_832e_11ea_8114_acde48001122row3_col3" class="data row3 col3" >713420.392025</td>
#             </tr>
#             <tr>
#                         <th id="T_6e4b6282_832e_11ea_8114_acde48001122level0_row4" class="row_heading level0 row4" >93</th>
#                         <td id="T_6e4b6282_832e_11ea_8114_acde48001122row4_col0" class="data row4 col0" >2020-04-24 00:00:00</td>
#                         <td id="T_6e4b6282_832e_11ea_8114_acde48001122row4_col1" class="data row4 col1" >721442.719136</td>
#                         <td id="T_6e4b6282_832e_11ea_8114_acde48001122row4_col2" class="data row4 col2" >703609.382486</td>
#                         <td id="T_6e4b6282_832e_11ea_8114_acde48001122row4_col3" class="data row4 col3" >740644.457470</td>
#             </tr>
#             <tr>
#                         <th id="T_6e4b6282_832e_11ea_8114_acde48001122level0_row5" class="row_heading level0 row5" >94</th>
#                         <td id="T_6e4b6282_832e_11ea_8114_acde48001122row5_col0" class="data row5 col0" >2020-04-25 00:00:00</td>
#                         <td id="T_6e4b6282_832e_11ea_8114_acde48001122row5_col1" class="data row5 col1" >745351.621922</td>
#                         <td id="T_6e4b6282_832e_11ea_8114_acde48001122row5_col2" class="data row5 col2" >724007.917081</td>
#                         <td id="T_6e4b6282_832e_11ea_8114_acde48001122row5_col3" class="data row5 col3" >765842.451759</td>
#             </tr>
#             <tr>
#                         <th id="T_6e4b6282_832e_11ea_8114_acde48001122level0_row6" class="row_heading level0 row6" >95</th>
#                         <td id="T_6e4b6282_832e_11ea_8114_acde48001122row6_col0" class="data row6 col0" >2020-04-26 00:00:00</td>
#                         <td id="T_6e4b6282_832e_11ea_8114_acde48001122row6_col1" class="data row6 col1" >768850.600613</td>
#                         <td id="T_6e4b6282_832e_11ea_8114_acde48001122row6_col2" class="data row6 col2" >745356.220600</td>
#                         <td id="T_6e4b6282_832e_11ea_8114_acde48001122row6_col3" class="data row6 col3" >792327.760047</td>
#             </tr>
#     </tbody></table>

# %%
#Plotting the forecast with the confidence interval of 98 percent
recovery_forecast_plot = model.plot(forecast)

# %%
#plotting the forcast for upcoming 7 days
recovery_forecast_plot = model.plot_components(forecast)

# %%
#copy the predictions folder
# !cp -r ~/Exploratory-Data-Analysis-COVID-19/visualizations/predictions ~/desktop/
