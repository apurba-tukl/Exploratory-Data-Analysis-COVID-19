# %% [markdown]
# ### This script uses the Facebook's open source software 'Prophet' to forecast the spread of COVID-19 worlwide for a defined future timeframe. We are using Prophet here beacuse the model to missing data, shifts in the trend and handles outliers well

# %% [markdown]
# ![alt text](https://cdn.weka-fachmedien.de/thumbs/media_uploads/images/1584632058-339-worrlgjo3.jpg.950x534.jpg)

# %%
#import the necessary packages
import pandas as pd
from fbprophet import Prophet

# Disable warnings 
import warnings
warnings.filterwarnings('ignore')

# %%
#loading the required datasets
df = pd.read_csv('../data/covid_19_data.csv')
df.rename(columns={'ObservationDate':'Date', 'Country/Region':'Country'}, inplace=True)
#df['Date'] = pd.to_datetime(df['Date'])
df.drop('SNo', axis=1, inplace = True)

df_confirmed = pd.read_csv("../data/time_series_covid_19_confirmed.csv")
df_recovered = pd.read_csv("../data/time_series_covid_19_recovered.csv")
df_deaths = pd.read_csv("../data/time_series_covid_19_deaths.csv")

df_confirmed.rename(columns={'Country/Region':'Country'}, inplace=True)
df_recovered.rename(columns={'Country/Region':'Country'}, inplace=True)
df_deaths.rename(columns={'Country/Region':'Country'}, inplace=True)

# %%
confirmed = df.groupby('Date').sum()['Confirmed'].reset_index()
deaths = df.groupby('Date').sum()['Deaths'].reset_index()
recovered = df.groupby('Date').sum()['Recovered'].reset_index()

# %% [markdown]
# The input to Prophet is always a dataframe with two columns: **ds** and **y**. The **ds (datestamp)** column should be of a format expected by Pandas, ideally YYYY-MM-DD for a date or YYYY-MM-DD HH:MM:SS for a timestamp. The y column must be numeric, and represents the measurement we wish to forecast.

# %%
confirmed['Confirmed'] = confirmed['Confirmed'].astype(int)
deaths['Deaths'] = deaths['Deaths'].astype(int)
recovered['Recovered'] = recovered['Recovered'] .astype(int)

confirmed.columns = ['ds','y']
deaths.columns = ['ds','y']
recovered.columns = ['ds','y']

confirmed.name = "Confirmed Cases"
deaths.name = "Death Cases"
recovered.name = "Recovery Cases"

# %% [markdown]
# ## Forecasting global confirmed cases using Prophet (Base model)
#
# Forecasting the comfirmed cases globally for a week's timeframe in advance, with 98% confidence interval. We are use the basic model here with no tweaking of seasonality-related parameters and additional regressors.

# %%
def covid_19_prediction(training_data, number_of_days_in_advance):
    
    model = Prophet(interval_width=0.98)
    model.fit(training_data)
    future_cases = model.make_future_dataframe(periods=number_of_days_in_advance)
    
    ### Forecasting the future confirmed cases globally for the next 1 week
    forecast = model.predict(future_cases)
    forecast_coming_week = forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail(7)
    forecast_coming_week = forecast_coming_week[1:]
    forecast_coming_week.ds = forecast_coming_week.ds.dt.day_name()
    forecast_coming_week.rename(columns = {'ds':'day_of_the_week','yhat':'prediction', 
                                     'yhat_lower':'prediction_lower_bound',
                                    'yhat_upper':'prediction_upper_bound'}, inplace=True)
    forecast_coming_week.set_index('day_of_the_week', inplace=True)
    forecast_coming_week['prediction' ] = round(forecast_coming_week.prediction).astype(int)
    forecast_coming_week['prediction_lower_bound'] = round(forecast_coming_week.prediction_lower_bound).astype(int)
    forecast_coming_week['prediction_upper_bound'] = round(forecast_coming_week.prediction_upper_bound).astype(int)
    
    ax = forecast_coming_week.plot(kind="bar",width=0.6, edgecolor='y',  figsize=(12,8), style='.-')
    ax.set_title("Predictions of %s in coming days including an upper an lower bound" %(training_data.name), fontsize=15)
    ax.set_ylabel("Count", fontsize=12)
    ax.set_xlabel("Day of the week", fontsize=12)

    for p in ax.patches:
        ax.annotate(str(p.get_height()), (p.get_x() * 1.02, p.get_height() * .8), family="monospace",
                    va='center', ha='center', horizontalalignment='right', verticalalignment='top', 
                    rotation=90, size=12)
        
    #saving the visualization
    fig= ax.get_figure()
    fig.tight_layout()
    fig.savefig("../visualizations/predictions/COVID-19_prediction_of_%s.png" %(training_data.name))   
    
    #Plotting the forecast with the confidence interval of 98 percent
    confirmed_forecast_plot = model.plot(forecast).savefig("../visualizations/predictions/COVID-19_prediction_fit_of_%s.png" %(training_data.name))  
    trained_model.plot_components(forecast).savefig("../visualizations/predictions/COVID-19_prediction_trend_of_%s.png" %(training_data.name))
    
    return model, forecast, forecast_coming_week

# %%
trained_model, forecast, forecast_coming_week = covid_19_prediction(confirmed, 7)
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
forecast_coming_week.style.background_gradient(cmap='Reds')
# Out:
# <style  type="text/css" >
#     #T_4007131e_767d_11ea_a517_f21898184071row0_col0 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_4007131e_767d_11ea_a517_f21898184071row0_col1 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_4007131e_767d_11ea_a517_f21898184071row0_col2 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_4007131e_767d_11ea_a517_f21898184071row1_col0 {
#             background-color:  #fdcdb9;
#             color:  #000000;
#         }    #T_4007131e_767d_11ea_a517_f21898184071row1_col1 {
#             background-color:  #fdcbb6;
#             color:  #000000;
#         }    #T_4007131e_767d_11ea_a517_f21898184071row1_col2 {
#             background-color:  #fdd0bc;
#             color:  #000000;
#         }    #T_4007131e_767d_11ea_a517_f21898184071row2_col0 {
#             background-color:  #fc8e6e;
#             color:  #000000;
#         }    #T_4007131e_767d_11ea_a517_f21898184071row2_col1 {
#             background-color:  #fc8b6b;
#             color:  #000000;
#         }    #T_4007131e_767d_11ea_a517_f21898184071row2_col2 {
#             background-color:  #fc9474;
#             color:  #000000;
#         }    #T_4007131e_767d_11ea_a517_f21898184071row3_col0 {
#             background-color:  #f24734;
#             color:  #000000;
#         }    #T_4007131e_767d_11ea_a517_f21898184071row3_col1 {
#             background-color:  #f44d38;
#             color:  #000000;
#         }    #T_4007131e_767d_11ea_a517_f21898184071row3_col2 {
#             background-color:  #f44f39;
#             color:  #000000;
#         }    #T_4007131e_767d_11ea_a517_f21898184071row4_col0 {
#             background-color:  #bc141a;
#             color:  #f1f1f1;
#         }    #T_4007131e_767d_11ea_a517_f21898184071row4_col1 {
#             background-color:  #b31218;
#             color:  #f1f1f1;
#         }    #T_4007131e_767d_11ea_a517_f21898184071row4_col2 {
#             background-color:  #c1161b;
#             color:  #f1f1f1;
#         }    #T_4007131e_767d_11ea_a517_f21898184071row5_col0 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_4007131e_767d_11ea_a517_f21898184071row5_col1 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_4007131e_767d_11ea_a517_f21898184071row5_col2 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }</style><table id="T_4007131e_767d_11ea_a517_f21898184071" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >prediction</th>        <th class="col_heading level0 col1" >prediction_lower_bound</th>        <th class="col_heading level0 col2" >prediction_upper_bound</th>    </tr>    <tr>        <th class="index_name level0" >day_of_the_week</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_4007131e_767d_11ea_a517_f21898184071level0_row0" class="row_heading level0 row0" >Sunday</th>
#                         <td id="T_4007131e_767d_11ea_a517_f21898184071row0_col0" class="data row0 col0" >1118305</td>
#                         <td id="T_4007131e_767d_11ea_a517_f21898184071row0_col1" class="data row0 col1" >1073825</td>
#                         <td id="T_4007131e_767d_11ea_a517_f21898184071row0_col2" class="data row0 col2" >1160609</td>
#             </tr>
#             <tr>
#                         <th id="T_4007131e_767d_11ea_a517_f21898184071level0_row1" class="row_heading level0 row1" >Monday</th>
#                         <td id="T_4007131e_767d_11ea_a517_f21898184071row1_col0" class="data row1 col0" >1172418</td>
#                         <td id="T_4007131e_767d_11ea_a517_f21898184071row1_col1" class="data row1 col1" >1126190</td>
#                         <td id="T_4007131e_767d_11ea_a517_f21898184071row1_col2" class="data row1 col2" >1216720</td>
#             </tr>
#             <tr>
#                         <th id="T_4007131e_767d_11ea_a517_f21898184071level0_row2" class="row_heading level0 row2" >Tuesday</th>
#                         <td id="T_4007131e_767d_11ea_a517_f21898184071row2_col0" class="data row2 col0" >1228226</td>
#                         <td id="T_4007131e_767d_11ea_a517_f21898184071row2_col1" class="data row2 col1" >1179387</td>
#                         <td id="T_4007131e_767d_11ea_a517_f21898184071row2_col2" class="data row2 col2" >1275632</td>
#             </tr>
#             <tr>
#                         <th id="T_4007131e_767d_11ea_a517_f21898184071level0_row3" class="row_heading level0 row3" >Wednesday</th>
#                         <td id="T_4007131e_767d_11ea_a517_f21898184071row3_col0" class="data row3 col0" >1285353</td>
#                         <td id="T_4007131e_767d_11ea_a517_f21898184071row3_col1" class="data row3 col1" >1227350</td>
#                         <td id="T_4007131e_767d_11ea_a517_f21898184071row3_col2" class="data row3 col2" >1338873</td>
#             </tr>
#             <tr>
#                         <th id="T_4007131e_767d_11ea_a517_f21898184071level0_row4" class="row_heading level0 row4" >Thursday</th>
#                         <td id="T_4007131e_767d_11ea_a517_f21898184071row4_col0" class="data row4 col0" >1344925</td>
#                         <td id="T_4007131e_767d_11ea_a517_f21898184071row4_col1" class="data row4 col1" >1294116</td>
#                         <td id="T_4007131e_767d_11ea_a517_f21898184071row4_col2" class="data row4 col2" >1404427</td>
#             </tr>
#             <tr>
#                         <th id="T_4007131e_767d_11ea_a517_f21898184071level0_row5" class="row_heading level0 row5" >Friday</th>
#                         <td id="T_4007131e_767d_11ea_a517_f21898184071row5_col0" class="data row5 col0" >1401412</td>
#                         <td id="T_4007131e_767d_11ea_a517_f21898184071row5_col1" class="data row5 col1" >1339892</td>
#                         <td id="T_4007131e_767d_11ea_a517_f21898184071row5_col2" class="data row5 col2" >1472502</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ## Forecasting global death cases using Prophet (Base model)
#
# Forecasting the death cases globally for a week's timeframe in advance, with 98% confidence interval. We are use the basic model here with no tweaking of seasonality-related parameters and additional regressors.

# %%
model = Prophet(interval_width=0.98)
model.fit(deaths)
future_death_cases = model.make_future_dataframe(periods=7)
#future_death_cases.tail(7)
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %% [markdown]
# ### Forecasting the future confirmed cases globally for the next 1 week

# %%
forecast = model.predict(future_death_cases)
forecast_coming_week = forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail(7)

# %%
forecast_coming_week.style.background_gradient(cmap='Reds')
# Out:
# <style  type="text/css" >
#     #T_23090c2e_767d_11ea_8eb5_f21898184071row0_col1 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_23090c2e_767d_11ea_8eb5_f21898184071row0_col2 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_23090c2e_767d_11ea_8eb5_f21898184071row0_col3 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_23090c2e_767d_11ea_8eb5_f21898184071row1_col1 {
#             background-color:  #fed8c7;
#             color:  #000000;
#         }    #T_23090c2e_767d_11ea_8eb5_f21898184071row1_col2 {
#             background-color:  #fedccd;
#             color:  #000000;
#         }    #T_23090c2e_767d_11ea_8eb5_f21898184071row1_col3 {
#             background-color:  #fedaca;
#             color:  #000000;
#         }    #T_23090c2e_767d_11ea_8eb5_f21898184071row2_col1 {
#             background-color:  #fca689;
#             color:  #000000;
#         }    #T_23090c2e_767d_11ea_8eb5_f21898184071row2_col2 {
#             background-color:  #fca285;
#             color:  #000000;
#         }    #T_23090c2e_767d_11ea_8eb5_f21898184071row2_col3 {
#             background-color:  #fca183;
#             color:  #000000;
#         }    #T_23090c2e_767d_11ea_8eb5_f21898184071row3_col1 {
#             background-color:  #fb7050;
#             color:  #000000;
#         }    #T_23090c2e_767d_11ea_8eb5_f21898184071row3_col2 {
#             background-color:  #fb7050;
#             color:  #000000;
#         }    #T_23090c2e_767d_11ea_8eb5_f21898184071row3_col3 {
#             background-color:  #fb7252;
#             color:  #000000;
#         }    #T_23090c2e_767d_11ea_8eb5_f21898184071row4_col1 {
#             background-color:  #e63328;
#             color:  #f1f1f1;
#         }    #T_23090c2e_767d_11ea_8eb5_f21898184071row4_col2 {
#             background-color:  #e32f27;
#             color:  #f1f1f1;
#         }    #T_23090c2e_767d_11ea_8eb5_f21898184071row4_col3 {
#             background-color:  #e83429;
#             color:  #f1f1f1;
#         }    #T_23090c2e_767d_11ea_8eb5_f21898184071row5_col1 {
#             background-color:  #b21218;
#             color:  #f1f1f1;
#         }    #T_23090c2e_767d_11ea_8eb5_f21898184071row5_col2 {
#             background-color:  #b21218;
#             color:  #f1f1f1;
#         }    #T_23090c2e_767d_11ea_8eb5_f21898184071row5_col3 {
#             background-color:  #b51318;
#             color:  #f1f1f1;
#         }    #T_23090c2e_767d_11ea_8eb5_f21898184071row6_col1 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_23090c2e_767d_11ea_8eb5_f21898184071row6_col2 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_23090c2e_767d_11ea_8eb5_f21898184071row6_col3 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }</style><table id="T_23090c2e_767d_11ea_8eb5_f21898184071" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >ds</th>        <th class="col_heading level0 col1" >yhat</th>        <th class="col_heading level0 col2" >yhat_lower</th>        <th class="col_heading level0 col3" >yhat_upper</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_23090c2e_767d_11ea_8eb5_f21898184071level0_row0" class="row_heading level0 row0" >73</th>
#                         <td id="T_23090c2e_767d_11ea_8eb5_f21898184071row0_col0" class="data row0 col0" >2020-04-04 00:00:00</td>
#                         <td id="T_23090c2e_767d_11ea_8eb5_f21898184071row0_col1" class="data row0 col1" >53357.943553</td>
#                         <td id="T_23090c2e_767d_11ea_8eb5_f21898184071row0_col2" class="data row0 col2" >49978.841305</td>
#                         <td id="T_23090c2e_767d_11ea_8eb5_f21898184071row0_col3" class="data row0 col3" >56736.810705</td>
#             </tr>
#             <tr>
#                         <th id="T_23090c2e_767d_11ea_8eb5_f21898184071level0_row1" class="row_heading level0 row1" >74</th>
#                         <td id="T_23090c2e_767d_11ea_8eb5_f21898184071row1_col0" class="data row1 col0" >2020-04-05 00:00:00</td>
#                         <td id="T_23090c2e_767d_11ea_8eb5_f21898184071row1_col1" class="data row1 col1" >56197.518516</td>
#                         <td id="T_23090c2e_767d_11ea_8eb5_f21898184071row1_col2" class="data row1 col2" >52399.993773</td>
#                         <td id="T_23090c2e_767d_11ea_8eb5_f21898184071row1_col3" class="data row1 col3" >59522.595254</td>
#             </tr>
#             <tr>
#                         <th id="T_23090c2e_767d_11ea_8eb5_f21898184071level0_row2" class="row_heading level0 row2" >75</th>
#                         <td id="T_23090c2e_767d_11ea_8eb5_f21898184071row2_col0" class="data row2 col0" >2020-04-06 00:00:00</td>
#                         <td id="T_23090c2e_767d_11ea_8eb5_f21898184071row2_col1" class="data row2 col1" >59114.837961</td>
#                         <td id="T_23090c2e_767d_11ea_8eb5_f21898184071row2_col2" class="data row2 col2" >55663.138895</td>
#                         <td id="T_23090c2e_767d_11ea_8eb5_f21898184071row2_col3" class="data row2 col3" >63041.295115</td>
#             </tr>
#             <tr>
#                         <th id="T_23090c2e_767d_11ea_8eb5_f21898184071level0_row3" class="row_heading level0 row3" >76</th>
#                         <td id="T_23090c2e_767d_11ea_8eb5_f21898184071row3_col0" class="data row3 col0" >2020-04-07 00:00:00</td>
#                         <td id="T_23090c2e_767d_11ea_8eb5_f21898184071row3_col1" class="data row3 col1" >62156.357524</td>
#                         <td id="T_23090c2e_767d_11ea_8eb5_f21898184071row3_col2" class="data row3 col2" >58332.990413</td>
#                         <td id="T_23090c2e_767d_11ea_8eb5_f21898184071row3_col3" class="data row3 col3" >65831.967239</td>
#             </tr>
#             <tr>
#                         <th id="T_23090c2e_767d_11ea_8eb5_f21898184071level0_row4" class="row_heading level0 row4" >77</th>
#                         <td id="T_23090c2e_767d_11ea_8eb5_f21898184071row4_col0" class="data row4 col0" >2020-04-08 00:00:00</td>
#                         <td id="T_23090c2e_767d_11ea_8eb5_f21898184071row4_col1" class="data row4 col1" >65313.491211</td>
#                         <td id="T_23090c2e_767d_11ea_8eb5_f21898184071row4_col2" class="data row4 col2" >61581.027618</td>
#                         <td id="T_23090c2e_767d_11ea_8eb5_f21898184071row4_col3" class="data row4 col3" >69175.633073</td>
#             </tr>
#             <tr>
#                         <th id="T_23090c2e_767d_11ea_8eb5_f21898184071level0_row5" class="row_heading level0 row5" >78</th>
#                         <td id="T_23090c2e_767d_11ea_8eb5_f21898184071row5_col0" class="data row5 col0" >2020-04-09 00:00:00</td>
#                         <td id="T_23090c2e_767d_11ea_8eb5_f21898184071row5_col1" class="data row5 col1" >68573.773163</td>
#                         <td id="T_23090c2e_767d_11ea_8eb5_f21898184071row5_col2" class="data row5 col2" >64400.395725</td>
#                         <td id="T_23090c2e_767d_11ea_8eb5_f21898184071row5_col3" class="data row5 col3" >72531.854469</td>
#             </tr>
#             <tr>
#                         <th id="T_23090c2e_767d_11ea_8eb5_f21898184071level0_row6" class="row_heading level0 row6" >79</th>
#                         <td id="T_23090c2e_767d_11ea_8eb5_f21898184071row6_col0" class="data row6 col0" >2020-04-10 00:00:00</td>
#                         <td id="T_23090c2e_767d_11ea_8eb5_f21898184071row6_col1" class="data row6 col1" >71649.160864</td>
#                         <td id="T_23090c2e_767d_11ea_8eb5_f21898184071row6_col2" class="data row6 col2" >67361.528836</td>
#                         <td id="T_23090c2e_767d_11ea_8eb5_f21898184071row6_col3" class="data row6 col3" >75917.795523</td>
#             </tr>
#     </tbody></table>

# %%
#Plotting the forecast with the confidence interval of 98 percent
death_forecast_plot = model.plot(forecast)

# %%
#plotting the forcast for upcoming 7 days
death_forecast_plot = model.plot_components(forecast)

# %% [markdown]
# ## Forecasting global recovery cases using Prophet (Base model)
#
# Forecasting the recovery cases globally for a week's timeframe in advance, with 98% confidence interval. We are use the basic model here with no tweaking of seasonality-related parameters and additional regressors.

# %%
model = Prophet(interval_width=0.98)
model.fit(recovered)
future_recovered_cases = model.make_future_dataframe(periods=7)
#future_death_cases.tail(7)
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %% [markdown]
# ### Forecasting the future confirmed cases globally for the next 1 week

# %%
forecast = model.predict(future_recovered_cases)
forecast_coming_week = forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail(7)

# %%
#printing the predicted values for coming week
forecast_coming_week.style.background_gradient(cmap='Reds')
# Out:
# <style  type="text/css" >
#     #T_25101ee2_767d_11ea_946d_f21898184071row0_col1 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_25101ee2_767d_11ea_946d_f21898184071row0_col2 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_25101ee2_767d_11ea_946d_f21898184071row0_col3 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_25101ee2_767d_11ea_946d_f21898184071row1_col1 {
#             background-color:  #fdd7c6;
#             color:  #000000;
#         }    #T_25101ee2_767d_11ea_946d_f21898184071row1_col2 {
#             background-color:  #fee0d2;
#             color:  #000000;
#         }    #T_25101ee2_767d_11ea_946d_f21898184071row1_col3 {
#             background-color:  #fdd4c2;
#             color:  #000000;
#         }    #T_25101ee2_767d_11ea_946d_f21898184071row2_col1 {
#             background-color:  #fca588;
#             color:  #000000;
#         }    #T_25101ee2_767d_11ea_946d_f21898184071row2_col2 {
#             background-color:  #fca183;
#             color:  #000000;
#         }    #T_25101ee2_767d_11ea_946d_f21898184071row2_col3 {
#             background-color:  #fcad90;
#             color:  #000000;
#         }    #T_25101ee2_767d_11ea_946d_f21898184071row3_col1 {
#             background-color:  #fb6e4e;
#             color:  #000000;
#         }    #T_25101ee2_767d_11ea_946d_f21898184071row3_col2 {
#             background-color:  #fa6849;
#             color:  #000000;
#         }    #T_25101ee2_767d_11ea_946d_f21898184071row3_col3 {
#             background-color:  #fb6e4e;
#             color:  #000000;
#         }    #T_25101ee2_767d_11ea_946d_f21898184071row4_col1 {
#             background-color:  #e32f27;
#             color:  #f1f1f1;
#         }    #T_25101ee2_767d_11ea_946d_f21898184071row4_col2 {
#             background-color:  #ea362a;
#             color:  #f1f1f1;
#         }    #T_25101ee2_767d_11ea_946d_f21898184071row4_col3 {
#             background-color:  #e63328;
#             color:  #f1f1f1;
#         }    #T_25101ee2_767d_11ea_946d_f21898184071row5_col1 {
#             background-color:  #b01217;
#             color:  #f1f1f1;
#         }    #T_25101ee2_767d_11ea_946d_f21898184071row5_col2 {
#             background-color:  #b11218;
#             color:  #f1f1f1;
#         }    #T_25101ee2_767d_11ea_946d_f21898184071row5_col3 {
#             background-color:  #af1117;
#             color:  #f1f1f1;
#         }    #T_25101ee2_767d_11ea_946d_f21898184071row6_col1 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_25101ee2_767d_11ea_946d_f21898184071row6_col2 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_25101ee2_767d_11ea_946d_f21898184071row6_col3 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }</style><table id="T_25101ee2_767d_11ea_946d_f21898184071" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >ds</th>        <th class="col_heading level0 col1" >yhat</th>        <th class="col_heading level0 col2" >yhat_lower</th>        <th class="col_heading level0 col3" >yhat_upper</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_25101ee2_767d_11ea_946d_f21898184071level0_row0" class="row_heading level0 row0" >73</th>
#                         <td id="T_25101ee2_767d_11ea_946d_f21898184071row0_col0" class="data row0 col0" >2020-04-04 00:00:00</td>
#                         <td id="T_25101ee2_767d_11ea_946d_f21898184071row0_col1" class="data row0 col1" >204073.939220</td>
#                         <td id="T_25101ee2_767d_11ea_946d_f21898184071row0_col2" class="data row0 col2" >190247.182682</td>
#                         <td id="T_25101ee2_767d_11ea_946d_f21898184071row0_col3" class="data row0 col3" >217785.341962</td>
#             </tr>
#             <tr>
#                         <th id="T_25101ee2_767d_11ea_946d_f21898184071level0_row1" class="row_heading level0 row1" >74</th>
#                         <td id="T_25101ee2_767d_11ea_946d_f21898184071row1_col0" class="data row1 col0" >2020-04-05 00:00:00</td>
#                         <td id="T_25101ee2_767d_11ea_946d_f21898184071row1_col1" class="data row1 col1" >211799.505971</td>
#                         <td id="T_25101ee2_767d_11ea_946d_f21898184071row1_col2" class="data row1 col2" >196336.247185</td>
#                         <td id="T_25101ee2_767d_11ea_946d_f21898184071row1_col3" class="data row1 col3" >226117.598717</td>
#             </tr>
#             <tr>
#                         <th id="T_25101ee2_767d_11ea_946d_f21898184071level0_row2" class="row_heading level0 row2" >75</th>
#                         <td id="T_25101ee2_767d_11ea_946d_f21898184071row2_col0" class="data row2 col0" >2020-04-06 00:00:00</td>
#                         <td id="T_25101ee2_767d_11ea_946d_f21898184071row2_col1" class="data row2 col1" >219782.533727</td>
#                         <td id="T_25101ee2_767d_11ea_946d_f21898184071row2_col2" class="data row2 col2" >205875.343462</td>
#                         <td id="T_25101ee2_767d_11ea_946d_f21898184071row2_col3" class="data row2 col3" >232529.641666</td>
#             </tr>
#             <tr>
#                         <th id="T_25101ee2_767d_11ea_946d_f21898184071level0_row3" class="row_heading level0 row3" >76</th>
#                         <td id="T_25101ee2_767d_11ea_946d_f21898184071row3_col0" class="data row3 col0" >2020-04-07 00:00:00</td>
#                         <td id="T_25101ee2_767d_11ea_946d_f21898184071row3_col1" class="data row3 col1" >228023.161474</td>
#                         <td id="T_25101ee2_767d_11ea_946d_f21898184071row3_col2" class="data row3 col2" >214362.059315</td>
#                         <td id="T_25101ee2_767d_11ea_946d_f21898184071row3_col3" class="data row3 col3" >242093.536070</td>
#             </tr>
#             <tr>
#                         <th id="T_25101ee2_767d_11ea_946d_f21898184071level0_row4" class="row_heading level0 row4" >77</th>
#                         <td id="T_25101ee2_767d_11ea_946d_f21898184071row4_col0" class="data row4 col0" >2020-04-08 00:00:00</td>
#                         <td id="T_25101ee2_767d_11ea_946d_f21898184071row4_col1" class="data row4 col1" >236725.071897</td>
#                         <td id="T_25101ee2_767d_11ea_946d_f21898184071row4_col2" class="data row4 col2" >220888.275979</td>
#                         <td id="T_25101ee2_767d_11ea_946d_f21898184071row4_col3" class="data row4 col3" >250393.311022</td>
#             </tr>
#             <tr>
#                         <th id="T_25101ee2_767d_11ea_946d_f21898184071level0_row5" class="row_heading level0 row5" >78</th>
#                         <td id="T_25101ee2_767d_11ea_946d_f21898184071row5_col0" class="data row5 col0" >2020-04-09 00:00:00</td>
#                         <td id="T_25101ee2_767d_11ea_946d_f21898184071row5_col1" class="data row5 col1" >245234.851418</td>
#                         <td id="T_25101ee2_767d_11ea_946d_f21898184071row5_col2" class="data row5 col2" >229912.626257</td>
#                         <td id="T_25101ee2_767d_11ea_946d_f21898184071row5_col3" class="data row5 col3" >259814.637789</td>
#             </tr>
#             <tr>
#                         <th id="T_25101ee2_767d_11ea_946d_f21898184071level0_row6" class="row_heading level0 row6" >79</th>
#                         <td id="T_25101ee2_767d_11ea_946d_f21898184071row6_col0" class="data row6 col0" >2020-04-10 00:00:00</td>
#                         <td id="T_25101ee2_767d_11ea_946d_f21898184071row6_col1" class="data row6 col1" >253215.982874</td>
#                         <td id="T_25101ee2_767d_11ea_946d_f21898184071row6_col2" class="data row6 col2" >237805.835667</td>
#                         <td id="T_25101ee2_767d_11ea_946d_f21898184071row6_col3" class="data row6 col3" >267712.536635</td>
#             </tr>
#     </tbody></table>

# %%
#Plotting the forecast with the confidence interval of 98 percent
recovery_forecast_plot = model.plot(forecast)

# %%
#plotting the forcast for upcoming 7 days
recovery_forecast_plot = model.plot_components(forecast)

# %%
forecast.name = "new"

# %%
forecast.name
# Out:
# 'new'
